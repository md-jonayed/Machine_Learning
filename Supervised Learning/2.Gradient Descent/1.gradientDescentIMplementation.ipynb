# %% [markdown]
# Gradient descent implementation

# %%
from sklearn.datasets import make_regression
import numpy as np

# %%
x,y = make_regression(n_samples=1000,n_features=1,n_informative=1,n_targets=1,noise=80,random_state=13)

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)

# %%
#applying OLS method
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([87.92927623])

# %%
reg.intercept_
# Out:
# 2.2468617721341904

# %%
plt.scatter(x,y)
plt.plot(x,reg.predict(x),color='red')

# %%
# lets apply gradient descent assuming slope m/b1=coef_value(87.92927623) and b0=0
yPred = ((87.92927623 * x)+0).reshape(1000)

# %%
plt.figure(figsize=(15,15))
plt.scatter(x,y)
plt.plot(x,reg.predict(x),color='red',label='OLS')
plt.plot(x,yPred,color='#00a65a',label='b=0')
plt.legend()
plt.show()

# %%
m=87.92927623
b=0

# %%
lossSlope = -2*np.sum(y-m*x.ravel()-b)
lossSlope
# Out:
# -4493.723544285498

# %%
# lets take learning rate 0.1
lr=0.001
stepSize=lr*lossSlope
stepSize
# Out:
# -4.493723544285499

# %%
#calculating new intercept
b= b-stepSize
b
# Out:
# 4.493723544285499

# %%
yPred1=((87.92927623*x)+b).reshape(1000)

# %%
plt.figure(figsize=(15,15))
plt.scatter(x,y)
plt.plot(x,reg.predict(x),color='red',label='OLS')
plt.plot(x,yPred1,color='#00a65a',label='b={}'.format(b))
plt.plot(x,yPred,color='#A3E4D7',label='b=0')
plt.legend()
plt.show()

# %%
#ITERATION 2
lossSlope=-2*np.sum(y-m*x.ravel()-b)
lossSlope
# Out:
# 4493.7235442855035

# %%
stepSize=lossSlope*lr
stepSize
# Out:
# 4.493723544285504

# %%
b=b-stepSize
b
# Out:
# -5.329070518200751e-15

# %%
yPred2 =((87.92927623*x)+b).reshape(1000)

# %%
plt.figure(figsize=(15,15))
plt.scatter(x,y)
plt.plot(x,reg.predict(x),color='red',label='OLS')
plt.plot(x,yPred2,color='#00a65a',label='b={}'.format(b))
plt.plot(x,yPred1,color='#A3E4D7',label='b={}'.format(b))
plt.plot(x,yPred,color='#A3E4D7',label='b=0')
plt.legend()
plt.show()

# %%
#itreration 3
lossSlope = -2 *np.sum(y-m*x.ravel()-b)
lossSlope
# Out:
# -4493.723544285505

# %%
stepSize = lr*lossSlope
stepSize
# Out:
# -4.493723544285506

# %%
b=b-stepSize
b
# Out:
# 4.4937235442855

# %%
yPred3 =((87.92927623*x)+b).reshape(1000)

# %%
plt.figure(figsize=(15,15))
plt.scatter(x,y)
plt.plot(x,reg.predict(x),color='red',label='OLS')
plt.plot(x,yPred3,color='#00a65a',label='b={}'.format(b))
plt.plot(x,yPred2,color='#A3E4D7',label='b={}'.format(b))
plt.plot(x,yPred1,color='#A3E4D7',label='b={}'.format(b))
plt.plot(x,yPred,color='#A3E4D7',label='b=0')
plt.legend()
plt.show()
